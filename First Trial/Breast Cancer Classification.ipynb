# %% [markdown]
# ## Replicating Explanation and Use of Uncertainty Quantified by Bayesian Neural Network Classifiers for Breast Histopathology Images
#
# This notebook documents an experimental replication of the research presented in the paper titled `Explanation and Use of Uncertainty Quantified by Bayesian Neural Network Classifiers for Breast Histopathology Images,` which investigated breast histopathology image classification using a Bayesian CNN approach. The specific experiment replicated here compares the classification performance of three models:
#
# *   TL-CNN: This model employs a VGG-16 architecture.
# *   bayesian-CNN: This is the original Bayesian CNN model presented in the paper.
# *   modified bayesian-CNN: This is the authors' proposed improvement to the original Bayesian CNN model.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
# Out:
# WARNING:tensorflow:From C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.

# %% [markdown]
# ## Data Preparation
#
# The experiment utilizes a publicly available breast histopathology image dataset from Kaggle, titled `Breast Histopathology Images` by Paul Mooney (2017).
#
# **Note : Due to ram limitation, the data limited into about 7000 images each classes**

# %%
data_dir =r".\B Histopatology Data"
os.listdir(data_dir)
# Out:
# ['cancer', 'normal']

# %% [markdown]
# ## Image preprocessing
#
# The images have a dimension of `3 x 50 x 50 (Depth x Height x Width)` and are converted to the uint8 format. `Pixel-wise` normalization is performed using a method from OpenCV.
#
# The dataset consists of two classes : cancer (1) and normal (0). By using `80% - 20%` data splitted into `train and validation`

# %%
def normalize_and_complement(x):
    x = x.astype('float64')
    return (255 - x) / 255.0

# %%
train_datagen = ImageDataGenerator(
                preprocessing_function=normalize_and_complement,
                validation_split = 0.2
                )

# %%
train_dt_generator = train_datagen.flow_from_directory(
    data_dir,
    shuffle=True,
    target_size=(50,50),
    subset= 'training',
)

validation_dt_generator= train_datagen.flow_from_directory(
    data_dir,
    shuffle=True,
    target_size=(50,50),
    subset= 'validation'
)
# Out:
# Found 12295 images belonging to 2 classes.
# Found 3072 images belonging to 2 classes.

# %% [markdown]
# ### TL-CNN
#
# The architecture of `TL-CNN` followed `VGG-16` and used the weight of `VGG-16` pre-trained on the `ImageNet` dataset for classification and performed `transfer learning` to classify the histopathological data.
#
# Based on paper, there were some strategies to solve the over-fitting from TL-CNN:
# 1. The use of L1 Regularization
# 2. The use of Dropout
# 3. The use of early st**opping (N**ot Use)
# 4. The use of cross-validation t**raining (**Not Use)

# %%
pretrained = tf.keras.applications.VGG16(weights = 'imagenet', include_top = False, input_shape = (50,50,3))
# Out:
# WARNING:tensorflow:From C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
for layer in pretrained.layers:
    layer.trainable = False

# %%
## TL_CNN (VGG-16 Architecture)
models = tf.keras.models.Sequential ([

    pretrained,
      
    # Fully Connected Layer
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4096, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.001)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4096, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.001)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(2, activation='softmax')

])

# %%
models.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %%
models.fit(train_dt_generator,
            epochs=60,
            batch_size =64,
            validation_data=validation_dt_generator,
            )
# Out:
# Epoch 1/60
# WARNING:tensorflow:From C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
#
# Epoch 45/60
# 385/385 [==============================] - 134s 349ms/step - loss: 2.8528 - accuracy: 0.7584 - val_loss: 2.9251 - val_accuracy: 0.6478
# Epoch 46/60
# 385/385 [==============================] - 134s 347ms/step - loss: 2.8510 - accuracy: 0.7566 - val_loss: 2.9482 - val_accuracy: 0.6432
# Epoch 47/60
# 385/385 [==============================] - 134s 347ms/step - loss: 2.8487 - accuracy: 0.7590 - val_loss: 2.9927 - val_accuracy: 0.6094
# Epoch 48/60
# 385/385 [==============================] - 134s 348ms/step - loss: 2.8499 - accuracy: 0.7570 - val_loss: 2.9640 - val_accuracy: 0.6562
# Epoch 49/60
# 385/385 [==============================] - 134s 348ms/step - loss: 2.8546 - accuracy: 0.7539 - val_loss: 2.9608 - val_accuracy: 0.6416
# Epoch 50/60
# 385/385 [==============================] - 131s 342ms/step - loss: 2.8487 - accuracy: 0.7599 - val_loss: 2.9524 - val_accuracy: 0.6491
# Epoch 51/60
# 385/385 [==============================] - 131s 341ms/step - loss: 2.8456 - accuracy: 0.7546 - val_loss: 2.9912 - val_accuracy: 0.6250
# Epoch 52/60
# 385/385 [==============================] - 133s 345ms/step - loss: 2.8467 - accuracy: 0.7565 - val_loss: 2.9110 - val_accuracy: 0.6628
# Epoch 53/60
# 385/385 [==============================] - 139s 361ms/step - loss: 2.8577 - accuracy: 0.7512 - val_loss: 2.9266 - val_accuracy: 0.6641
# Epoch 54/60
# 385/385 [==============================] - 143s 371ms/step - loss: 2.8491 - accuracy: 0.7567 - val_loss: 2.9907 - val_accuracy: 0.6279
# Epoch 55/60
# 385/385 [==============================] - 144s 374ms/step - loss: 2.8509 - accuracy: 0.7569 - val_loss: 2.9478 - val_accuracy: 0.6615
# Epoch 56/60
# 385/385 [==============================] - 148s 384ms/step - loss: 2.8511 - accuracy: 0.7566 - val_loss: 2.9800 - val_accuracy: 0.6162
# Epoch 57/60
# 385/385 [==============================] - 143s 372ms/step - loss: 2.8519 - accuracy: 0.7564 - val_loss: 2.8911 - val_accuracy: 0.6810
# Epoch 58/60
# 385/385 [==============================] - 141s 367ms/step - loss: 2.8473 - accuracy: 0.7587 - val_loss: 2.9854 - val_accuracy: 0.6113
# Epoch 59/60
# 385/385 [==============================] - 143s 372ms/step - loss: 2.8466 - accuracy: 0.7594 - val_loss: 2.9971 - val_accuracy: 0.5879
# Epoch 60/60
# 385/385 [==============================] - 144s 374ms/step - loss: 2.8491 - accuracy: 0.7601 - val_loss: 2.9674 - val_accuracy: 0.6410

# %%
plt.plot(models.history.history['accuracy'], label='Train Accuracy')
plt.plot(models.history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy TL-CNN')
plt.legend()
plt.savefig('Acc Graph TLCNN.jpg', dpi = 600)
plt.show()

# %% [markdown]
# ### Bayesian-CNN
#
# All convolution layers are fixed as `(3 x 3)` with `stride = 1` and max pool layers are `(2 x 2)` with `stride = 2`

# %%
bayesian_cnn = tf.keras.models.Sequential ([
    #block 1
    tfp.layers.Convolution2DFlipout(16, (3,3), activation ='relu', input_shape=(50,50,3), strides = 1), #input
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = 2),    

    #block 2
    tf.keras.layers.Conv2D(32, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.Conv2D(32, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = 2),

    #block 3
    tf.keras.layers.Conv2D(64, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.Conv2D(128, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.Conv2D(256, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = 2),    

    #Fully Connected
    tf.keras.layers.Flatten(),
    tfp.layers.DenseFlipout(512, activation = 'relu'), #FC1
    tfp.layers.DenseFlipout(2, activation ='sigmoid') # Output
        ])

# %%
bayesian_cnn.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
train_dt_generator = train_datagen.flow_from_directory(
    data_dir,
    shuffle=True,
    target_size=(50,50),
    subset= 'training',
)

validation_dt_generator= train_datagen.flow_from_directory(
    data_dir,
    shuffle=True,
    target_size=(50,50),
    subset= 'validation'
)
# Out:
# Found 12295 images belonging to 2 classes.
# Found 3072 images belonging to 2 classes.

# %%
bayesian_cnn.fit(train_dt_generator,
            epochs=60,
            batch_size =128,
            validation_data=validation_dt_generator,
            )
# Out:
# Epoch 1/60
# WARNING:tensorflow:From C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 385/385 [==============================] - 26s 62ms/step - loss: 1230677.3750 - accuracy: 0.5757 - val_loss: 1132639.3750 - val_accuracy: 0.5055
# Epoch 2/60
# 385/385 [==============================] - 18s 47ms/step - loss: 1037326.8125 - accuracy: 0.4974 - val_loss: 942239.4375 - val_accuracy: 0.5003
# Epoch 3/60
# 385/385 [==============================] - 19s 48ms/step - loss: 850102.1250 - accuracy: 0.5031 - val_loss: 759170.8125 - val_accuracy: 0.5179
# Epoch 4/60
# 385/385 [==============================] - 18s 48ms/step - loss: 672170.3125 - accuracy: 0.5009 - val_loss: 586900.0625 - val_accuracy: 0.4984
# Epoch 5/60
# 385/385 [==============================] - 19s 50ms/step - loss: 507074.0938 - accuracy: 0.4996 - val_loss: 430040.3438 - val_accuracy: 0.5029
# Epoch 6/60
# 385/385 [==============================] - 18s 47ms/step - loss: 360303.4062 - accuracy: 0.5068 - val_loss: 293993.8750 - val_accuracy: 0.4919
# Epoch 7/60
# 385/385 [==============================] - 18s 45ms/step - loss: 236715.2188 - accuracy: 0.4987 - val_loss: 183853.0625 - val_accuracy: 0.5205
# Epoch 8/60
# 385/385 [==============================] - 16s 42ms/step - loss: 140888.7031 - accuracy: 0.4970 - val_loss: 102636.6016 - val_accuracy: 0.4967
# Epoch 9/60
# 385/385 [==============================] - 17s 45ms/step - loss: 73992.3438 - accuracy: 0.5042 - val_loss: 49634.0039 - val_accuracy: 0.5075
# Epoch 10/60
# 385/385 [==============================] - 19s 50ms/step - loss: 33227.0352 - accuracy: 0.5102 - val_loss: 20043.0488 - val_accuracy: 0.5013
# Epoch 11/60
# 385/385 [==============================] - 17s 45ms/step - loss: 12255.8564 - accuracy: 0.5018 - val_loss: 6469.9585 - val_accuracy: 0.5078
# Epoch 12/60
# 385/385 [==============================] - 15s 40ms/step - loss: 3568.0439 - accuracy: 0.5068 - val_loss: 1588.9614 - val_accuracy: 0.5137
# Epoch 13/60
# 385/385 [==============================] - 15s 38ms/step - loss: 778.8146 - accuracy: 0.5131 - val_loss: 281.4912 - val_accuracy: 0.5140
# Epoch 14/60
# 385/385 [==============================] - 14s 36ms/step - loss: 121.3744 - accuracy: 0.5139 - val_loss: 34.3191 - val_accuracy: 0.5140
# Epoch 15/60
# 385/385 [==============================] - 14s 36ms/step - loss: 13.2001 - accuracy: 0.5139 - val_loss: 3.2298 - val_accuracy: 0.5140
# Epoch 16/60
# 385/385 [==============================] - 14s 38ms/step - loss: 1.5056 - accuracy: 0.5139 - val_loss: 0.8031 - val_accuracy: 0.5140
# Epoch 17/60
# 385/385 [==============================] - 14s 37ms/step - loss: 0.7228 - accuracy: 0.5139 - val_loss: 0.6952 - val_accuracy: 0.5140
# Epoch 18/60
# 385/385 [==============================] - 14s 38ms/step - loss: 0.6934 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 19/60
# 385/385 [==============================] - 15s 39ms/step - loss: 0.6930 - accuracy: 0.5155 - val_loss: 0.6930 - val_accuracy: 0.5153
# Epoch 20/60
# 385/385 [==============================] - 16s 43ms/step - loss: 0.6929 - accuracy: 0.5131 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 21/60
# 385/385 [==============================] - 16s 40ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 22/60
# 385/385 [==============================] - 16s 41ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 23/60
# 385/385 [==============================] - 16s 40ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 24/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 25/60
# 385/385 [==============================] - 15s 40ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 26/60
# 385/385 [==============================] - 15s 38ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 27/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 28/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 29/60
# 385/385 [==============================] - 14s 37ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 30/60
# 385/385 [==============================] - 16s 41ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 31/60
# 385/385 [==============================] - 18s 46ms/step - loss: 0.6929 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 32/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 33/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 34/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6929 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 35/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 36/60
# 385/385 [==============================] - 14s 37ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 37/60
# 385/385 [==============================] - 15s 38ms/step - loss: 0.6957 - accuracy: 0.5103 - val_loss: 0.6969 - val_accuracy: 0.4863
# Epoch 38/60
# 385/385 [==============================] - 16s 42ms/step - loss: 0.6935 - accuracy: 0.5059 - val_loss: 0.6932 - val_accuracy: 0.5104
# Epoch 39/60
# 385/385 [==============================] - 18s 48ms/step - loss: 0.7243 - accuracy: 0.5115 - val_loss: 0.6968 - val_accuracy: 0.4958
# Epoch 40/60
# 385/385 [==============================] - 16s 42ms/step - loss: 0.6935 - accuracy: 0.5100 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 41/60
# 385/385 [==============================] - 17s 44ms/step - loss: 0.6928 - accuracy: 0.5097 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 42/60
# 385/385 [==============================] - 16s 43ms/step - loss: 0.6929 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 43/60
# 385/385 [==============================] - 15s 39ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 44/60
# 385/385 [==============================] - 16s 42ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 45/60
# 385/385 [==============================] - 17s 45ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 46/60
# 385/385 [==============================] - 15s 39ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 47/60
# 385/385 [==============================] - 15s 38ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 48/60
# 385/385 [==============================] - 14s 35ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 49/60
# 385/385 [==============================] - 14s 36ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 50/60
# 385/385 [==============================] - 14s 35ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 51/60
# 385/385 [==============================] - 14s 35ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 52/60
# 385/385 [==============================] - 15s 40ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 53/60
# 385/385 [==============================] - 16s 42ms/step - loss: 0.6928 - accuracy: 0.5110 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 54/60
# 385/385 [==============================] - 16s 43ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 55/60
# 385/385 [==============================] - 15s 40ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 56/60
# 385/385 [==============================] - 15s 39ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 57/60
# 385/385 [==============================] - 17s 44ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 58/60
# 385/385 [==============================] - 15s 40ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 59/60
# 385/385 [==============================] - 17s 44ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6928 - val_accuracy: 0.5140
# Epoch 60/60
# 385/385 [==============================] - 17s 43ms/step - loss: 0.6928 - accuracy: 0.5139 - val_loss: 0.6929 - val_accuracy: 0.5140

# %%
plt.plot(bayesian_cnn.history.history['accuracy'], label='Train Accuracy')
plt.plot(bayesian_cnn.history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Bayesian-CNN')
plt.legend()
plt.savefig('Acc Graph Bayesian-CNN.jpg', dpi = 600)
plt.show()

# %% [markdown]
# ### Modified Bayesian-CNN
#
# In Fully Connected Layer 1, instead of using ReLU, it uses a stochastic-adaptive ReLU

# %%
alpha = tf.Variable(initial_value=0.1, trainable = True)

def stochastic_adaptive_relu(x, alpha):
    f_k = x
    return alpha * f_k * tf.cast(f_k > 0, dtype=tf.float32)

# %%
class CustomDense(tfp.layers.DenseFlipout):
    def __init__ (self, units, **kwargs):
        super(CustomDense, self).__init__(units, **kwargs)

    def call(self, inputs):
        output = super(CustomDense, self).call(inputs)
        return stochastic_adaptive_relu(output, alpha)

# %%
modified_bayesian_cnn = tf.keras.models.Sequential ([
    #block 1
    tfp.layers.Convolution2DFlipout(32, (3,3), activation ='relu', input_shape=(50,50,3), strides = 1), #input
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = 2),    

    #block 2
    tf.keras.layers.Conv2D(64, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.Conv2D(64, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = 2),

    #block 3
    tf.keras.layers.Conv2D(128, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.Conv2D(128, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.Conv2D(128, (3,3), activation ='relu', strides = 1),
    tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = 2),    

    #Fully Connected
    tf.keras.layers.Flatten(),
    CustomDense(256), #FC1 with Stochastic-Adaptive Learning ReLU Activation Function
    tfp.layers.DenseFlipout(2, activation ='sigmoid') # Output
        ])
# Out:
# C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\tensorflow_probability\python\layers\util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# C:\Users\Andreas Sahir\AppData\Local\anaconda3\envs\pre-screening\lib\site-packages\tensorflow_probability\python\layers\util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(

# %%
modified_bayesian_cnn.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# %%
modified_bayesian_cnn.fit(train_dt_generator,
            epochs=60,
            batch_size =64,
            validation_data=validation_dt_generator,
            )
# Out:
# Epoch 1/60
# 385/385 [==============================] - 20s 47ms/step - loss: 332562.1562 - accuracy: 0.6659 - val_loss: 329946.0000 - val_accuracy: 0.7546
# Epoch 2/60
# 385/385 [==============================] - 17s 45ms/step - loss: 327388.9688 - accuracy: 0.7119 - val_loss: 324831.9062 - val_accuracy: 0.7406
# Epoch 3/60
# 385/385 [==============================] - 16s 41ms/step - loss: 322315.6875 - accuracy: 0.7057 - val_loss: 319795.5938 - val_accuracy: 0.7438
# Epoch 4/60
# 385/385 [==============================] - 16s 42ms/step - loss: 317299.5312 - accuracy: 0.6749 - val_loss: 314805.5938 - val_accuracy: 0.7246
# Epoch 5/60
# 385/385 [==============================] - 15s 39ms/step - loss: 312328.8438 - accuracy: 0.6498 - val_loss: 309846.4062 - val_accuracy: 0.6771
# Epoch 44/60
# 385/385 [==============================] - 18s 46ms/step - loss: 130403.9297 - accuracy: 0.5134 - val_loss: 128293.9766 - val_accuracy: 0.5169
# Epoch 45/60
# 385/385 [==============================] - 15s 40ms/step - loss: 126204.3594 - accuracy: 0.5122 - val_loss: 124109.9141 - val_accuracy: 0.5127
# Epoch 46/60
# 385/385 [==============================] - 18s 46ms/step - loss: 122038.7578 - accuracy: 0.5127 - val_loss: 119963.9766 - val_accuracy: 0.5124
# Epoch 47/60
# 385/385 [==============================] - 17s 44ms/step - loss: 117909.9766 - accuracy: 0.5111 - val_loss: 115857.9062 - val_accuracy: 0.5101
# Epoch 48/60
# 385/385 [==============================] - 15s 38ms/step - loss: 113823.2500 - accuracy: 0.5134 - val_loss: 111793.0078 - val_accuracy: 0.5104
# Epoch 49/60
# 385/385 [==============================] - 16s 42ms/step - loss: 109781.5859 - accuracy: 0.5125 - val_loss: 107771.0938 - val_accuracy: 0.5114
# Epoch 50/60
# 385/385 [==============================] - 17s 45ms/step - loss: 105784.2500 - accuracy: 0.5123 - val_loss: 103793.9766 - val_accuracy: 0.5176
# Epoch 51/60
# 385/385 [==============================] - 17s 45ms/step - loss: 101829.7812 - accuracy: 0.5118 - val_loss: 99862.9688 - val_accuracy: 0.5101
# Epoch 52/60
# 385/385 [==============================] - 17s 44ms/step - loss: 97922.0938 - accuracy: 0.5135 - val_loss: 95979.8984 - val_accuracy: 0.5199
# Epoch 53/60
# 385/385 [==============================] - 17s 45ms/step - loss: 94064.9453 - accuracy: 0.5125 - val_loss: 92146.4688 - val_accuracy: 0.5146
# Epoch 54/60
# 385/385 [==============================] - 18s 48ms/step - loss: 90258.9922 - accuracy: 0.5159 - val_loss: 88364.6016 - val_accuracy: 0.5160
# Epoch 55/60
# 385/385 [==============================] - 16s 42ms/step - loss: 86501.1172 - accuracy: 0.5138 - val_loss: 84636.3047 - val_accuracy: 0.5133
# Epoch 56/60
# 385/385 [==============================] - 16s 42ms/step - loss: 82799.1406 - accuracy: 0.5144 - val_loss: 80963.0234 - val_accuracy: 0.5137
# Epoch 57/60
# 385/385 [==============================] - 18s 47ms/step - loss: 79153.9766 - accuracy: 0.5123 - val_loss: 77347.1016 - val_accuracy: 0.5163
# Epoch 58/60
# 385/385 [==============================] - 16s 42ms/step - loss: 75569.9531 - accuracy: 0.5126 - val_loss: 73790.3828 - val_accuracy: 0.5072
# Epoch 59/60
# 385/385 [==============================] - 15s 39ms/step - loss: 72038.9609 - accuracy: 0.5108 - val_loss: 70294.6406 - val_accuracy: 0.5117
# Epoch 60/60
# 385/385 [==============================] - 16s 42ms/step - loss: 68577.0859 - accuracy: 0.5131 - val_loss: 66862.1562 - val_accuracy: 0.5169

# %%
plt.plot(modified_bayesian_cnn.history.history['accuracy'], label='Train Accuracy')
plt.plot(modified_bayesian_cnn.history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Modified Bayesian-CNN')
plt.legend()
plt.savefig('Acc Graph Modified Bayesian-CNN.jpg', dpi = 600)
plt.show()
